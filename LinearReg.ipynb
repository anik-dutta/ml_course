# %%
import pandas as pd
import numpy as np
data=pd.read_csv('Headbrain.csv')
print(data.shape)
data.head()
# Out:
# (237, 4)
#    Gender  Age Range  Head size  Brain Weights
# 0       1          1       4512           1530
# 1       1          1       3738           1297
# 2       1          1       4261           1335
# 3       1          1       3777           1282
# 4       1          1       4177           1590

# %%
x=data['Head size'].values
y=data['Brain Weights'].values
xm=np.mean(x)
ym=np.mean(y)
print(xm,ym)
size=len(data['Head size'])
for  i in range(size):
    sum1=sum1+(x[i]-xm)*(y[i]-ym)
    sum2=sum2+(x[i]-xm)**2  
m=sum1/sum2
print(m)

c=ym-m*xm
print(c)
for i in x:
    yp=m*x+c
z=abs(sum(yp-ym))
print(z)
rs=z/(y_sum**2)
print(rs)
# Out:
# 3633.9915611814345 1282.873417721519
# 0.26419087240743555
# 322.8060168517371
# 1.0686562745831907e-11
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-ef192939bb61> in <module>
#      17 z=abs(sum(yp-ym))
#      18 print(z)
# ---> 19 rs=z/(y_sum**2)
#      20 print(rs)
#
# NameError: name 'y_sum' is not defined

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv('Headbrain.csv')
#z=data.head()
x1=np.mean(data['Head size'])
print(x1)
y1=np.mean(data['Brain Weights'])
print(y1)
sum1=0
sum2=0
x=data['Head size']
y=data['Brain Weights']
size=len(data['Head size'])
for  i in range(size):
    sum1=sum1+(x[i]-x1)*(y[i]-y1)
    sum2=sum2+(x[i]-x1)**2
m=sum1/sum2
print(m)
c=y1-m*x1
print(c)
lis=[]
for z in range(size):
        yp=np.array(m*x[z]+c)
        lis.append(yp)
data['predict y']=lis
print(data)
nu=0
de=0
for z in range(size):
    nu=nu+((lis[z]-y1)**2)
    de=de+((y[z]-y1)**2)
r=nu/de
print(r)
# Out:
# 3633.9915611814345
# 1282.873417721519
# 0.26342933948939945
# 325.57342104944223
#      Gender  Age Range  Head size  Brain Weights           predict y
# 0         1          1       4512           1530  1514.1666008256125
# 1         1          1       3738           1297  1310.2722920608173
# 2         1          1       4261           1335  1448.0458366137732
# 3         1          1       3777           1282   1320.546036300904
# 4         1          1       4177           1590  1425.9177720966638
# 5         1          1       3585           1300  1269.9676031189392
# 6         1          1       3785           1400  1322.6534710168191
# 7         1          1       3559           1255   1263.118440292215
# 8         1          1       3613           1355  1277.3436246246424
# 9         1          1       3982           1375   1374.549050896231
# 10        1          1       3443           1340  1232.5606369114446
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split

df=pd.read_csv('Headbrain.csv')
df.head()
# Out:
#    Gender  Age Range  Head size  Brain Weights
# 0       1          1       4512           1530
# 1       1          1       3738           1297
# 2       1          1       4261           1335
# 3       1          1       3777           1282
# 4       1          1       4177           1590

# %%
x=df['Head size'].values
print(x.shape)
print(type(size))
m=len(x)
x=x.reshape(m,-1)
print(x.shape)
y=df['Brain Weights'].values
y=y.reshape(m,-1)
# Out:
# (237,)
# <class 'int'>
# (237, 1)

# %%
#creating a learner(regmodel)

regmodel=linear_model.LinearRegression()
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=4)
regmodel.fit(x_train,y_train)   #.fit is used for creating a target function
a=regmodel.predict(x_test)      #predict is used for test set
print(a[4])
print(y_test[4])
r2=regmodel.score(x,y)         #
print(r2)
# Out:
# [1229.02194904]
# [1235]
# 0.6389640869366903
