# %%
a,b,c,d=10,11,11,3
print ("a is the highest") if a>=b and a>=c and a>=d else print ("b is the highest") if b>=a and b>=c and b>=d \
else print ("c is the highest") if c>=a and c>=b and c>=d else print("d is the highest")
print ("a is the lowest") if b>=a and c>=a and d>=a else print ("b is the lowest") if a>=b and c>=b and d>=b \
else print ("c is the lowest") if b>=c and a>=c and d>=c else print ("d is the lowest")
# Out:
# b is the highest
# d is the lowest

# %%
x,y=0,1
print(x,y)
x,y=y,x+y print(y) if x==0 and y==1
x,y=y=x+y print(y) 
x,y=y,x+y print(y)
# Out:
#   File "<ipython-input-7-361a96da60ee>", line 3
#     x,y=y,x+y print(y) if x==0 and y==1
#                   ^
# SyntaxError: invalid syntax
