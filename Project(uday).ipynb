# %%
import pandas as pd
import numpy as np
df1=pd.read_csv("cancer.csv")
#dtf=pd.DataFrame(df)
#df.isnull().sum()
#df.describe()
#df.info()
#df.ndim
df=df1.drop('Unnamed: 32',axis=1)
#df.head(10)
for i in df:
    print(i)
# Out:
# id
# diagnosis
# radius_mean
# texture_mean
# perimeter_mean
# area_mean
# smoothness_mean
# compactness_mean
# concavity_mean
# concave points_mean
# symmetry_mean
# fractal_dimension_mean
# radius_se
# texture_se
# perimeter_se
# area_se
# smoothness_se
# compactness_se
# concavity_se
# concave points_se
# symmetry_se
# fractal_dimension_se
# radius_worst
# texture_worst
# perimeter_worst
# area_worst
# smoothness_worst
# compactness_worst
# concavity_worst
# concave points_worst
# symmetry_worst
# fractal_dimension_worst

# %%
#Univariate Analysis

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
df=pd.read_csv("cancer.csv")
df.drop('Unnamed: 32',axis=1)
plt.title("Radious_Mean Analysis")
sns.boxplot(y=df.radius_mean)
plt.show()

# %%
plt.title("Texture_Mean Analysis")
sns.boxplot(y=df.texture_mean)
plt.show()

# %%
plt.title("Perimeter_Mean Analysis")
sns.boxplot(y=df.perimeter_mean)

# %%
plt.title("Area_Mean Analysis")
sns.boxplot(y=df.area_mean)
plt.show()

# %%
plt.title("Smoothness_Mean Analysis")
sns.boxplot(y=df.smoothness_mean)
plt.show()

# %%
plt.title("Compactness_Mean Analysis")
sns.boxplot(y=df.compactness_mean)
plt.show()

# %%
plt.title("Concavity_Mean Analysis")
sns.boxplot(y=df.concavity_mean)
plt.show()

# %%
df=df.rename(columns = {'concave points_mean':'concavepoints_mean'})
plt.title("Concave Points_Mean Analysis")
sns.boxplot(y=df.concavepoints_mean)
plt.show()

# %%
plt.title("Symmetry Mean Analysis")
sns.boxplot(y=df.symmetry_mean)
plt.show()

# %%
plt.title("Fractal_Dimension_Mean Analysis")
sns.boxplot(y=df.fractal_dimension_mean)
plt.show()

# %%
#Standard Error Analysis

plt.title("Radious_Se Analysis")
sns.boxplot(y=df.radius_se)
plt.show()

# %%
plt.title("Texture_Se Analysis")
sns.boxplot(y=df.texture_se)
plt.show()

# %%
plt.title("Perimeter_Se Analysis")
sns.boxplot(y=df.perimeter_se)

# %%
plt.title("Area_Se Analysis")
sns.boxplot(y=df.area_se)
plt.show()

# %%
plt.title("Smoothness_Se Analysis")
sns.boxplot(y=df.smoothness_se)
plt.show()

# %%
plt.title("Compactness_Se Analysis")
sns.boxplot(y=df.compactness_se)
plt.show()

# %%
plt.title("Concavity_Se Analysis")
sns.boxplot(y=df.concavity_se)
plt.show()

# %%
df=df.rename(columns = {'concave points_se':'concavepoints_se'})
plt.title("Concave Points_se Analysis")
sns.boxplot(y=df.concavepoints_se)
plt.show()

# %%
plt.title("Symmetry Se Analysis")
sns.boxplot(y=df.symmetry_se)
plt.show()

# %%
plt.title("Fractal_Dimension_Se Analysis")
sns.boxplot(y=df.fractal_dimension_se)
plt.show()

# %%
#Worst Case Analysis

plt.title("Radious_Worst Analysis")
sns.boxplot(y=df.radius_worst)
plt.show()

# %%
plt.title("Texture_Worst Analysis")
sns.boxplot(y=df.texture_worst)
plt.show()

# %%
plt.title("Perimeter_Worst Analysis")
sns.boxplot(y=df.perimeter_worst)

# %%
plt.title("Area_Worst Analysis")
sns.boxplot(y=df.area_worst)
plt.show()

# %%
plt.title("Smoothness_Worst Analysis")
sns.boxplot(y=df.smoothness_worst)
plt.show()

# %%
plt.title("Compactness_Worst Analysis")
sns.boxplot(y=df.compactness_worst)
plt.show()

# %%
plt.title("Concavity_Worst Analysis")
sns.boxplot(y=df.concavity_worst)
plt.show()

# %%
df=df.rename(columns = {'concave points_worst':'concavepoints_worst'})
plt.title("Concave Points_Worst Analysis")
sns.boxplot(y=df.concavepoints_worst)
plt.show()

# %%
plt.title("Symmetry Worst Analysis")
sns.boxplot(y=df.symmetry_worst)
plt.show()

# %%
plt.title("Fractal_Dimension_Worst Analysis")
sns.boxplot(y=df.fractal_dimension_worst)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
df1=pd.read_csv("cancer.csv")
#plt.hist(df.radius_mean)
#plt.show()

# %%
#without outliers

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
df=pd.read_csv("cancer.csv")
df.drop('Unnamed: 32',axis=1)
df['radius_mean'].describe()
# Out:
# count    569.000000
# mean      14.127292
# std        3.524049
# min        6.981000
# 25%       11.700000
# 50%       13.370000
# 75%       15.780000
# max       28.110000
# Name: radius_mean, dtype: float64

# %%
df_out=df[(df.radius_mean<15.78)&(df.radius_mean>11.70)]
plt.title("Radious_Mean Without Outliers Analysis")
sns.boxplot(y=df_out.radius_mean)
plt.show()

# %%
df_out['radius_mean']=np.log(df_out['radius_mean'])
sns.distplot(df_out['radius_mean'],color='maroon')
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['texture_mean'].describe()
# Out:
# count    569.000000
# mean      19.289649
# std        4.301036
# min        9.710000
# 25%       16.170000
# 50%       18.840000
# 75%       21.800000
# max       39.280000
# Name: texture_mean, dtype: float64

# %%
df_out=df[(df.texture_mean<21.80)&(df.texture_mean>16.17)]
plt.title("Texture_Mean Without  Outliers Analysis")
sns.boxplot(y=df_out.texture_mean)
plt.show()

# %%
df_out['texture_mean']=np.log(df_out['texture_mean'])
sns.distplot(df_out['texture_mean'])
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['perimeter_mean'].describe()
# Out:
# count    569.000000
# mean      91.969033
# std       24.298981
# min       43.790000
# 25%       75.170000
# 50%       86.240000
# 75%      104.100000
# max      188.500000
# Name: perimeter_mean, dtype: float64

# %%
df_out=df[(df.perimeter_mean<104.10)&(df.perimeter_mean>75.17)]
plt.title("Perimeter_Mean Without Outliers Analysis")
sns.boxplot(y=df_out.perimeter_mean)
plt.show()

# %%
df_out['perimeter_mean']=np.log(df_out['perimeter_mean'])
sns.distplot(df_out['perimeter_mean'])
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['area_mean'].describe()
# Out:
# count     569.000000
# mean      654.889104
# std       351.914129
# min       143.500000
# 25%       420.300000
# 50%       551.100000
# 75%       782.700000
# max      2501.000000
# Name: area_mean, dtype: float64

# %%
df_out=df[(df.area_mean<782.70)&(df.area_mean>420.30)]
plt.title("Area_Mean Without Outliers Analysis")
sns.boxplot(y=df_out.area_mean)
plt.show()

# %%
df_out['area_mean']=np.log(df_out['area_mean'])
sns.distplot(df_out['area_mean'])
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['smoothness_mean'].describe()
# Out:
# count    569.000000
# mean       0.096360
# std        0.014064
# min        0.052630
# 25%        0.086370
# 50%        0.095870
# 75%        0.105300
# max        0.163400
# Name: smoothness_mean, dtype: float64

# %%
df_out=df[(df.smoothness_mean<0.10530)&(df.smoothness_mean>0.086370)]
plt.title("Smoothness_Mean Without Outliers Analysis")
sns.boxplot(y=df_out.smoothness_mean)
plt.show()

# %%
df_out['smoothness_mean']=np.log(df_out['smoothness_mean'])
sns.distplot(df_out['smoothness_mean'])
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['compactness_mean'].describe()
# Out:
# count    569.000000
# mean       0.104341
# std        0.052813
# min        0.019380
# 25%        0.064920
# 50%        0.092630
# 75%        0.130400
# max        0.345400
# Name: compactness_mean, dtype: float64

# %%
df_out=df[(df.compactness_mean<0.13040)&(df.compactness_mean>0.064920)]
plt.title("Compactness_Mean Analysis Without Outliers")
sns.boxplot(y=df_out.compactness_mean)
plt.show()

# %%
df_out['compactness_se']=np.log(df_out['compactness_se'])
sns.distplot(df_out['compactness_se'])
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['concavity_mean'].describe()
# Out:
# count    569.000000
# mean       0.088799
# std        0.079720
# min        0.000000
# 25%        0.029560
# 50%        0.061540
# 75%        0.130700
# max        0.426800
# Name: concavity_mean, dtype: float64

# %%
df_out=df[(df.concavity_mean<0.130700)&(df.concavity_mean>0.029560)]
plt.title("Concavity_Mean Analysis Without Outliers")
sns.boxplot(y=df_out.concavity_mean)
plt.show()

# %%
df=df.rename(columns = {'concave points_mean':'concavepoints_mean'})
df['concavepoints_mean'].describe()
# Out:
# count    140.000000
# mean       0.037857
# std        0.018884
# min        0.008507
# 25%        0.024528
# 50%        0.031585
# 75%        0.049805
# max        0.091760
# Name: concavepoints_mean, dtype: float64

# %%
df_out=df.rename(columns = {'concave points_mean':'concavepoints_mean'})
df_out=df[(df.concavepoints_mean<0.049805)&(df.concavepoints_mean>0.24528)]
plt.title("Concave_Points_Mean Analysis Without Outliers")
sns.boxplot(y=df_out.concavepoints_mean)
plt.show()

# %%
df=df_out.rename(columns = {'concave points_mean':'concavepoints_mean'})
df_out['concavepoints_mean']=np.sqrt(df_out['concavepoints_mean'])
sns.distplot(df_out['concavepoints_mean'])
# Out:
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['symmetry_mean'].describe()
# Out:
# count    569.000000
# mean       0.181162
# std        0.027414
# min        0.106000
# 25%        0.161900
# 50%        0.179200
# 75%        0.195700
# max        0.304000
# Name: symmetry_mean, dtype: float64

# %%
df_out=df[(df.symmetry_mean<0.195700)&(df.symmetry_mean>0.161900)]
plt.title("Symmetry_Points_Mean Analysis Without Outliers")
sns.boxplot(y=df_out.symmetry_mean)
plt.show()

# %%
df_out['symmetry_mean']=np.log(df_out['symmetry_mean'])
sns.distplot(df_out['symmetry_mean'])
# Out:
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['fractal_dimension_mean'].describe()
# Out:
# count    569.000000
# mean       0.062798
# std        0.007060
# min        0.049960
# 25%        0.057700
# 50%        0.061540
# 75%        0.066120
# max        0.097440
# Name: fractal_dimension_mean, dtype: float64

# %%
df_out=df[(df.fractal_dimension_mean<0.066120)&(df.fractal_dimension_mean>0.057700)]
plt.title("Fractal_Dimension_Mean Analysis Without Outliers")
sns.boxplot(y=df_out.fractal_dimension_mean)
plt.show()

# %%
df_out['fractal_dimension_mean']=np.log(df_out['fractal_dimension_mean'])
sns.distplot(df_out['fractal_dimension_mean'])
# Out:
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['radius_se'].describe()
# Out:
# count    282.000000
# mean       0.318864
# std        0.167911
# min        0.115300
# 25%        0.220900
# 50%        0.273100
# 75%        0.369975
# max        1.370000
# Name: radius_se, dtype: float64

# %%
df_out=df[(df.radius_se<0.369975)&(df.radius_se>0.220900)]
plt.title("Radious_Se Without Outliers Analysis")
sns.boxplot(y=df_out.radius_se)
plt.show()

# %%
df_out['radius_se']=np.log(df_out['radius_se'])
sns.distplot(df_out['radius_se'],color='maroon')
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['texture_se'].describe()
# Out:
# count    282.000000
# mean       1.121228
# std        0.480743
# min        0.362100
# 25%        0.779200
# 50%        1.036500
# 75%        1.362250
# max        3.647000
# Name: texture_se, dtype: float64

# %%
df_out=df[(df.texture_se<1.362250)&(df.texture_se>0.779200)]
plt.title("Texture_Se Without Outliers Analysis")
sns.boxplot(y=df_out.texture_se)
plt.show()

# %%
df_out['texture_se']=np.log(df_out['texture_se'])
sns.distplot(df_out['texture_se'],color='maroon')
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['perimeter_se'].describe()
# Out:
# count    282.000000
# mean       2.276896
# std        1.180181
# min        0.757000
# 25%        1.540500
# 50%        2.057000
# 75%        2.626250
# max       10.120000
# Name: perimeter_se, dtype: float64

# %%
df_out=df[(df.perimeter_se<1.362250)&(df.perimeter_se>0.779200)]
plt.title("Perimeter_Se Without Outliers Analysis")
sns.boxplot(y=df_out.perimeter_se)
plt.show()
#Distplot Without Outliers
df_out['perimeter_se']=np.log(df_out['perimeter_se'])
sns.distplot(df_out['perimeter_se'],color='maroon')
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['area_se'].describe()
# Out:
# count    282.000000
# mean      27.011550
# std       17.003166
# min        8.955000
# 25%       18.025000
# 50%       23.030000
# 75%       31.007500
# max      176.500000
# Name: area_se, dtype: float64

# %%
df_out=df[(df.area_se<31.07500)&(df.area_se>18.02500)]
plt.title("Area_Se Without Outliers Analysis")
sns.boxplot(y=df_out.area_se)
plt.show()
#Distplot Without Outliers
df_out['area_se']=np.log(df_out['area_se'])
sns.distplot(df_out['area_se'],color='maroon')
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['smoothness_se'].describe()
# Out:
# count    282.000000
# mean       0.006226
# std        0.002016
# min        0.002826
# 25%        0.004869
# 50%        0.005846
# 75%        0.007288
# max        0.014180
# Name: smoothness_se, dtype: float64

# %%
df_out=df[(df.smoothness_se<0.007288)&(df.smoothness_se>0.002826)]
plt.title("Smoothness_Se Without Outliers Analysis")
sns.boxplot(y=df_out.smoothness_se)
plt.show()
#Distplot Without Outliers
df_out['smoothness_se']=np.log(df_out['smoothness_se'])
sns.distplot(df_out['smoothness_se'],color='maroon')
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['compactness_se'].describe()
# Out:
# count    282.000000
# mean      -3.979115
# std        0.642045
# min       -6.095937
# 25%       -4.412948
# 50%       -4.015174
# 75%       -3.511989
# max       -1.999522
# Name: compactness_se, dtype: float64

# %%
df_out=df[(df.compactness_se<-3.511989)&(df.compactness_se>-4.412948)]
plt.title("Compactness_Se Without Outliers Analysis")
sns.boxplot(y=df_out.compactness_se)
plt.show()
#Distplot Without Outliers
df_out['compactness_se']=np.log(df_out['compactness_se'])
sns.distplot(df_out['compactness_se'],color='maroon')
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in log
#
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# G:\Anaconda\lib\site-packages\numpy\core\_methods.py:28: RuntimeWarning: invalid value encountered in reduce
# ...

# %%
df['concavity_se'].describe()
# Out:
# count    282.000000
# mean       0.027241
# std        0.020708
# min        0.000000
# 25%        0.013980
# 50%        0.020750
# 75%        0.035337
# max        0.143500
# Name: concavity_se, dtype: float64

# %%
df_out=df[(df.concavity_se<0.035337)&(df.concavity_se>0.013980)]
plt.title("Concavity_Se Without Outliers Analysis")
sns.boxplot(y=df_out.concavity_se)
plt.show()
#Distplot Without Outliers
df_out['concavity_se']=np.log(df_out['concavity_se'])
sns.distplot(df_out['concavity_se'],color='maroon')
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df_out=df.rename(columns = {'concave points_se':'concavepoints_se'})
df_out['concavepoints_se'].describe()
# Out:
# count    140.000000
# mean       0.010119
# std        0.003025
# min        0.005383
# 25%        0.008131
# 50%        0.009548
# 75%        0.011855
# max        0.022580
# Name: concavepoints_se, dtype: float64

# %%
df_out=df.rename(columns = {'concave points_se':'concavepoints_se'})
df_out=df[(df.concavepoints_se<0.011855)&(df.concavepoints_se>0.008131)]
plt.title("Concavepoints_Se Without Outliers Analysis")
sns.boxplot(y=df_out.concavepoints_se)
plt.show()
#Distplot Without Outliers
df_out['concavepoints_se']=np.log(df_out['concavepoints_se'])
sns.distplot(df_out['concavepoints_se'],color='maroon')
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['symmetry_se'].describe()
# Out:
# count    140.000000
# mean       0.017730
# std        0.004834
# min        0.007882
# 25%        0.014540
# 50%        0.017355
# 75%        0.019645
# max        0.033730
# Name: symmetry_se, dtype: float64

# %%
df_out=df[(df.symmetry_se<0.019645)&(df.symmetry_se>0.014540)]
plt.title("Symmetry_Se Without Outliers Analysis")
sns.boxplot(y=df_out.symmetry_se)
plt.show()
#Distplot Without Outliers
df_out['symmetry_se']=np.log(df_out['symmetry_se'])
sns.distplot(df_out['symmetry_se'],color='maroon')
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['fractal_dimension_se'].describe()
# Out:
# count    140.000000
# mean       0.002849
# std        0.001194
# min        0.001219
# 25%        0.001975
# 50%        0.002512
# 75%        0.003425
# max        0.009423
# Name: fractal_dimension_se, dtype: float64

# %%
df_out=df[(df.fractal_dimension_se<0.003425)&(df.fractal_dimension_se>0.001975)]
plt.title("Fractal_Dimension_Se Without Outliers Analysis")
sns.boxplot(y=df_out.fractal_dimension_se)
plt.show()
#Distplot Without Outliers
df_out['fractal_dimension_se']=np.log(df_out['fractal_dimension_se'])
sns.distplot(df_out['fractal_dimension_se'],color='maroon')
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['radius_worst'].describe()
# Out:
# count    140.00000
# mean      15.35100
# std        1.65744
# min       12.57000
# 25%       14.01500
# 50%       15.05000
# 75%       16.45250
# max       20.11000
# Name: radius_worst, dtype: float64

# %%
df_out=df[(df.radius_worst<16.45250)&(df.radius_worst>14.01500)]
plt.title("Rdius_Worst Without Outliers Analysis")
sns.boxplot(y=df_out.radius_worst)
plt.show()
#Distplot Without Outliers
df_out['radius_worst']=np.log(df_out['radius_worst'])
sns.distplot(df_out['radius_worst'],color='maroon')
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['texture_worst'].describe()
# Out:
# count    140.000000
# mean      25.266929
# std        6.089665
# min       14.200000
# 25%       20.497500
# 50%       25.180000
# 75%       29.315000
# max       49.540000
# Name: texture_worst, dtype: float64

# %%
df_out=df[(df.texture_worst<29.315000)&(df.texture_worst>14.01500)]
plt.title("Texture_Worst Without Outliers Analysis")
sns.boxplot(y=df_out.texture_worst)
plt.show()
#Distplot Without Outliers
df_out['texture_worst']=np.log(df_out['texture_worst'])
sns.distplot(df_out['texture_worst'],color='maroon')
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['perimeter_worst'].describe()
# Out:
# count    140.000000
# mean     100.168071
# std       11.501002
# min       79.570000
# 25%       90.472500
# 50%       98.605000
# 75%      108.725000
# max      129.300000
# Name: perimeter_worst, dtype: float64

# %%
df_out=df[(df.perimeter_worst<108.725000)&(df.perimeter_worst>90.472500)]
plt.title("perimeter_Worst Without Outliers Analysis")
sns.boxplot(y=df_out.perimeter_worst)
plt.show()
#Distplot Without Outliers
df_out['perimeter_worst']=np.log(df_out['perimeter_worst'])
sns.distplot(df_out['perimeter_worst'],color='maroon')
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['area_worst'].describe()
# Out:
# count     140.000000
# mean      729.210000
# std       162.142947
# min       489.500000
# 25%       601.650000
# 50%       698.800000
# 75%       830.500000
# max      1269.000000
# Name: area_worst, dtype: float64

# %%
df_out=df[(df.area_worst<830.5000)&(df.area_worst>601.65000)]
plt.title("Area_Worst Without Outliers Analysis")
sns.boxplot(y=df_out.area_worst)
plt.show()
#Distplot Without Outliers
df_out['area_worst']=np.log(df_out['area_worst'])
sns.distplot(df_out['area_worst'],color='maroon')
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['smoothness_worst'].describe()
# Out:
# count    140.000000
# mean       0.132543
# std        0.021184
# min        0.084840
# 25%        0.119800
# 50%        0.131100
# 75%        0.144300
# max        0.222600
# Name: smoothness_worst, dtype: float64

# %%
df_out=df[(df.smoothness_worst<0.144300)&(df.smoothness_worst>0.119800)]
plt.title("Smoothness_Worst Without Outliers Analysis")
sns.boxplot(y=df_out.smoothness_worst)
plt.show()
#Distplot Without Outliers
df_out['smoothness_worst']=np.log(df_out['smoothness_worst'])
sns.distplot(df_out['smoothness_worst'],color='maroon')
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['compactness_worst'].describe()
# Out:
# count    140.000000
# mean       0.229957
# std        0.104706
# min        0.051310
# 25%        0.161925
# 50%        0.200600
# 75%        0.281400
# max        0.664300
# Name: compactness_worst, dtype: float64

# %%
df_out=df[(df.compactness_worst<0.281400)&(df.compactness_worst>0.161925)]
plt.title("Compactness_Worst Without Outliers Analysis")
sns.boxplot(y=df_out.compactness_worst)
plt.show()
#Distplot Without Outliers
df_out['compactness_worst']=np.log(df_out['compactness_worst'])
sns.distplot(df_out['compactness_worst'],color='maroon')
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['concavity_worst'].describe()
# Out:
# count    140.000000
# mean       0.226394
# std        0.112286
# min        0.023980
# 25%        0.142300
# 50%        0.188250
# 75%        0.297375
# max        0.570300
# Name: concavity_worst, dtype: float64

# %%
df_out=df[(df.concavity_worst<0.297375)&(df.concavity_worst>0.142300)]
plt.title("Concavity_Worst Without Outliers Analysis")
sns.boxplot(y=df_out.concavity_worst)
plt.show()
#Distplot Without Outliers
df_out['concavity_worst']=np.log(df_out['concavity_worst'])
sns.distplot(df_out['concavity_worst'],color='maroon')
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df_out=df.rename(columns = {'concave points_worst':'concavepoints_worst'})
df_out['concavepoints_worst'].describe()
# Out:
# count    140.000000
# mean       0.106106
# std        0.042429
# min        0.028990
# 25%        0.077790
# 50%        0.097525
# 75%        0.131325
# max        0.270100
# Name: concavepoints_worst, dtype: float64

# %%
df_out=df.rename(columns = {'concave points_worst':'concavepoints_worst'})
df_out=df_out[(df_out.concavepoints_worst<0.131325)&(df_out.concavepoints_worst>0.142300)]
plt.title("Concavepoints_Worst Without Outliers Analysis")
sns.boxplot(y=df_out.concavepoints_worst)
plt.show()
#Distplot Without Outliers
df_out['concavepoints_worst']=np.log(df_out['concavepoints_worst'])
sns.distplot(df_out['concavepoints_worst'],color='maroon')
# Out:
# G:\Anaconda\lib\site-packages\numpy\lib\histograms.py:815: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %%
df['symmetry_worst'].describe()
# Out:
# count    140.000000
# mean       0.289121
# std        0.051247
# min        0.156500
# 25%        0.252875
# 50%        0.277300
# 75%        0.318700
# max        0.475300
# Name: symmetry_worst, dtype: float64

# %%
df_out=df[(df.symmetry_worst<0.318700)&(df.symmetry_worst>0.252875)]
plt.title("Symmetry_Worst Without Outliers Analysis")
sns.boxplot(y=df_out.symmetry_worst)
plt.show()
#Distplot Without Outliers
df_out['symmetry_worst']=np.log(df_out['symmetry_worst'])
sns.distplot(df_out['symmetry_worst'],color='maroon')
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df['fractal_dimension_worst'].describe()
# Out:
# count    140.000000
# mean       0.081140
# std        0.014454
# min        0.055040
# 25%        0.069953
# 50%        0.078460
# 75%        0.086782
# max        0.127500
# Name: fractal_dimension_worst, dtype: float64

# %%
df_out=df[(df.fractal_dimension_worst<0.086782)&(df.fractal_dimension_worst>0.069953)]
plt.title("Fractal_Dimension_Worst Without Outliers Analysis")
sns.boxplot(y=df_out.fractal_dimension_worst)
plt.show()
#Distplot Without Outliers
df_out['fractal_dimension_worst']=np.log(df_out['fractal_dimension_worst'])
sns.distplot(df_out['fractal_dimension_worst'],color='maroon')
# Out:
# G:\Anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# G:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
import pandas as pd
import numpy as np
df1=pd.read_csv("cancer.csv")
#dtf=pd.DataFrame(df)
#df.isnull().sum()
#df.describe()
#df.info()
#df.ndim
df=df1.drop('Unnamed: 32',axis=1)
#df.head(10)
for i in df:
    print(i)
# Out:
# id
# diagnosis
# radius_mean
# texture_mean
# perimeter_mean
# area_mean
# smoothness_mean
# compactness_mean
# concavity_mean
# concave points_mean
# symmetry_mean
# fractal_dimension_mean
# radius_se
# texture_se
# perimeter_se
# area_se
# smoothness_se
# compactness_se
# concavity_se
# concave points_se
# symmetry_se
# fractal_dimension_se
# radius_worst
# texture_worst
# perimeter_worst
# area_worst
# smoothness_worst
# compactness_worst
# concavity_worst
# concave points_worst
# symmetry_worst
# fractal_dimension_worst

# %%
from sklearn.model_selection import train_test_split
x=df.drop('diagnosis',axis=1)
y=df['diagnosis']
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=4)
from sklearn.linear_model import LogisticRegression
logmodel=LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# C:\Users\sankha mondal\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
predictions=logmodel.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
res=confusion_matrix(y_test,predictions)
res
# Out:
# array([[ 19, 135],
#        [  6,  68]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
print("Accuracy is: ",accuracy_score(y_test,predictions)*100)
# Out:
# Accuracy is:  38.15789473684211

# %%
from sklearn.feature_selection import SelectKBest

# %%
from sklearn.feature_selection import chi2

# %%
X_new=SelectKBest(chi2,20).fit_transform(x,y)

# %%
print(X_new.shape)
# Out:
# (569, 20)

# %%
n=len(y)

# %%
df=df.rename(columns = {'concave points_worst':'concavepoints_worst'})
zero_not_accepted=['concavepoints_worst']
for column in zero_not_accepted:
    df[column]=df[column].replace(0,np.NaN)
    mean=int(df[column].mean(skipna=True))
    df[column]=df[column].replace(np.NaN,mean)
    print(df[column])
# Out:
# 0      0.26540
# 1      0.18600
# 2      0.24300
# 3      0.25750
# 4      0.16250
# 5      0.17410
# 6      0.19320
# 7      0.15560
# 8      0.20600
# 9      0.22100
# 10     0.09975
# 11     0.18100
# 12     0.17670
# 13     0.11190
# 14     0.22080
# 15     0.17120
# 16     0.16090
# 17     0.20730
# 18     0.23880
# 19     0.12880
# 20     0.07283
# 21     0.06227
# 22     0.23930
# 23     0.20090
# 24     0.20950
# 25     0.25500
# 26     0.27010
# 27     0.14900
# 28     0.20240
# 29     0.14560
#         ...
# 539    0.05000
# 540    0.06918
# 541    0.12050
# 542    0.10950
# 543    0.07958
# 544    0.06845
# 545    0.07174
# 546    0.02381
# 547    0.08333
# 548    0.03846
# 549    0.03264
# 550    0.00000
# 551    0.06413
# 552    0.06498
# 553    0.02564
# 554    0.06493
# 555    0.09127
# 556    0.02232
# 557    0.00000
# 558    0.11050
# 559    0.09653
# 560    0.10480
# 561    0.00000
# 562    0.23560
# 563    0.25420
# 564    0.22160
# 565    0.16280
# 566    0.14180
# ...

# %%
import seaborn as sns
df[column]=np.log(df[column])
sns.distplot(df[column])
# Out:
# C:\Users\sankha mondal\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-12-0f0285e66820> in <module>
#       1 import seaborn as sns
#       2 df[column]=np.log(df[column])
# ----> 3 sns.distplot(df[column])
#
# ~\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     213     if hist:
#     214         if bins is None:
# --> 215             bins = min(_freedman_diaconis_bins(a), 50)
#     216         hist_kws.setdefault("alpha", 0.4)
#     217         if LooseVersion(mpl.__version__) < LooseVersion("2.2"):
#
# ~\Anaconda3\lib\site-packages\seaborn\distributions.py in _freedman_diaconis_bins(a)
# ...

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2,f_classif

# %%
x=df.drop("diagnosis",axis=1)
y=df["diagnosis"]

# %%
bestfeature=SelectKBest(score_func=f_classif,k=5)
fit=bestfeature.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-192887cac1c1> in <module>
#       1 bestfeature=SelectKBest(score_func=f_classif,k=5)
# ----> 2 fit=bestfeature.fit(x,y)
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_selection\univariate_selection.py in fit(self, X, y)
#     339         self : object
#     340         """
# --> 341         X, y = check_X_y(X, y, ['csr', 'csc'], multi_output=True)
#     342
#     343         if not callable(self.score_func):
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
#     755                     warn_on_dtype=warn_on_dtype,
# ...
