# %%
import pandas as pd
import numpy as np
data=pd.read_csv('Headbrain.csv')
print(data.shape)
data.head()
# Out:
# (237, 4)
#    Gender  Age Range  Head size  Brain Weights
# 0       1          1       4512           1530
# 1       1          1       3738           1297
# 2       1          1       4261           1335
# 3       1          1       3777           1282
# 4       1          1       4177           1590

# %%
x=data['Head size'].values
y=data['Brain Weights'].values
xm=np.mean(x)
print(xm,ym)
ym=np.mean(y)
for i in x:
    x_sum=abs(np.sum(x-xm))

print(x_sum)
for i in y:
    y_sum=abs(np.sum(y-ym))
print(y_sum)
m=(x_sum*y_sum)/(x_sum*x_sum)
print(m)
c=ym-m*xm
print(c)
for i in x:
    yp=m*x+c
z=abs(sum(yp-ym))
print(z)
rs=z/(y_sum**2)
print(rs)
# Out:
# 3633.9915611814345 1282.873417721519
# 2.546585164964199e-11
# 1.8189894035458565e-12
# 0.07142857142857142
# 1023.3025919228451
# 5.002220859751105e-12
# 1511828488192.0
