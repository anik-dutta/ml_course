# %%
import pandas as pd
df=pd.read_csv("cancer.csv")
df.head(150)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M       17.990         10.38          122.80     1001.0
# 1      842517         M       20.570         17.77          132.90     1326.0
# 2    84300903         M       19.690         21.25          130.00     1203.0
# 3    84348301         M       11.420         20.38           77.58      386.1
# 4    84358402         M       20.290         14.34          135.10     1297.0
# 5      843786         M       12.450         15.70           82.57      477.1
# 6      844359         M       18.250         19.98          119.60     1040.0
# 7    84458202         M       13.710         20.83           90.20      577.9
# 8      844981         M       13.000         21.82           87.50      519.8
# 9    84501001         M       12.460         24.04           83.97      475.9
# 10     845636         M       16.020         23.24          102.70      797.8
# ...

# %%
df.skew()
# Out:
# id                         6.473752
# radius_mean                0.942380
# texture_mean               0.650450
# perimeter_mean             0.990650
# area_mean                  1.645732
# smoothness_mean            0.456324
# compactness_mean           1.190123
# concavity_mean             1.401180
# concave points_mean        1.171180
# symmetry_mean              0.725609
# fractal_dimension_mean     1.304489
# radius_se                  3.088612
# texture_se                 1.646444
# perimeter_se               3.443615
# area_se                    5.447186
# smoothness_se              2.314450
# compactness_se             1.902221
# concavity_se               5.110463
# concave points_se          1.444678
# symmetry_se                2.195133
# fractal_dimension_se       3.923969
# radius_worst               1.103115
# texture_worst              0.498321
# perimeter_worst            1.128164
# area_worst                 1.859373
# smoothness_worst           0.415426
# ...

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
cdf=df.drop('id',axis=1).drop('Unnamed: 32',axis=1)

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# compactness_se             569 non-null float64
# ...

# %%
cdf.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.boxplot(cdf['radius_mean'])
plt.show()
import seaborn as sns

# %%
cdf.skew()
# Out:
# radius_mean                0.942380
# texture_mean               0.650450
# perimeter_mean             0.990650
# area_mean                  1.645732
# smoothness_mean            0.456324
# compactness_mean           1.190123
# concavity_mean             1.401180
# concave points_mean        1.171180
# symmetry_mean              0.725609
# fractal_dimension_mean     1.304489
# radius_se                  3.088612
# texture_se                 1.646444
# perimeter_se               3.443615
# area_se                    5.447186
# smoothness_se              2.314450
# compactness_se             1.902221
# concavity_se               5.110463
# concave points_se          1.444678
# symmetry_se                2.195133
# fractal_dimension_se       3.923969
# radius_worst               1.103115
# texture_worst              0.498321
# perimeter_worst            1.128164
# area_worst                 1.859373
# smoothness_worst           0.415426
# compactness_worst          1.473555
# ...

# %%
sns.distplot(cdf['radius_mean'],hist=True,color='grey')

# %%
sns.distplot((np.sqrt(cdf['radius_mean'])),hist=True,color='grey')

# %%
sns.distplot(cdf['texture_mean'],hist=True,color='grey')

# %%
sns.distplot(cdf['perimeter_mean'],hist=True,color='grey')

# %%
sns.distplot(cdf['area_mean'],hist=True,color='grey')

# %%
sns.distplot(cdf['smoothness_mean'],hist=True,color='grey')

# %%
sns.distplot(cdf['compactness_mean'],hist=True,color='grey')

# %%
sns.distplot(cdf['concavity_mean'],hist=True,color='grey')

# %%
sns.distplot(cdf['concave points_mean'],hist=True,color='grey')

# %%
sns.distplot(cdf['symmetry_mean'],hist=True,color='grey')

# %%
sns.distplot(cdf['fractal_dimension_mean'],hist=True,color='grey')

# %%
sns.distplot(cdf['radius_se'],hist=True,color='grey')

# %%
sns.distplot(cdf['texture_se'],hist=True,color='grey')

# %%
sns.distplot(cdf['perimeter_se'],hist=True,color='grey')

# %%
sns.distplot(cdf['area_se'],hist=True,color='grey')

# %%
sns.barplot(y="radius_mean",x="diagnosis",hue="diagnosis",data=df,palette='autumn')

# %%
sns.boxplot(x='radius_mean',y='diagnosis',data=df)

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# compactness_se             569 non-null float64
# ...

# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

# %%
cdf.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
y=cdf.diagnosis
x=cdf.drop('diagnosis',axis=1)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=4)
from sklearn.linear_model import LogisticRegression
legmodel=LogisticRegression()
legmodel.fit(x_train,y_train)
# Out:
# F:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
predictions=legmodel.predict(x_test)

# %%
res=confusion_matrix(y_test,predictions)
res
# Out:
# array([[109,   8],
#        [  6,  48]], dtype=int64)

# %%
cdf.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
q1=cdf.quantile(0.25)
q3=cdf.quantile(0.75)
iqr=q3-q1
print(q1)
print(q3)
# Out:
# radius_mean                 11.700000
# texture_mean                16.170000
# perimeter_mean              75.170000
# area_mean                  420.300000
# smoothness_mean              0.086370
# compactness_mean             0.064920
# concavity_mean               0.029560
# concave points_mean          0.020310
# symmetry_mean                0.161900
# fractal_dimension_mean       0.057700
# radius_se                    0.232400
# texture_se                   0.833900
# perimeter_se                 1.606000
# area_se                     17.850000
# smoothness_se                0.005169
# compactness_se               0.013080
# concavity_se                 0.015090
# concave points_se            0.007638
# symmetry_se                  0.015160
# fractal_dimension_se         0.002248
# radius_worst                13.010000
# texture_worst               21.080000
# perimeter_worst             84.110000
# area_worst                 515.300000
# smoothness_worst             0.116600
# ...

# %%
cdf_n=cdf[~((cdf<(q1-1.5*iqr))|(cdf>(q3+1.5*iqr))).any(axis=1)]
cdf_n.shape
# Out:
# (398, 31)

# %%
cdf_n.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   398.000000    398.000000      398.000000   398.000000
# mean     13.376209     18.505879       86.403266   570.547990
# std       2.484104      3.911148       16.841597   222.883241
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.710000     15.702500       75.065000   420.350000
# 50%      12.995000     18.175000       84.065000   518.300000
# 75%      14.640000     20.755000       94.730000   664.200000
# max      20.590000     29.810000      137.800000  1320.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       398.000000        398.000000      398.000000           398.000000
# mean          0.093271          0.086260        0.060442             0.035902
# std           0.012066          0.034979        0.049068             0.025625
# min           0.062510          0.019380        0.000000             0.000000
# ...

# %%
plt.boxplot(cdf_n['radius_mean'])
plt.show()

# %%
#outlier detection

import numpy as np
import pandas as pd
outliers=[]
def detect_outlier(cdf):
    threshold=1
    mean_1=np.mean(cdf.radius_mean)
    std_1=np.std(cdf.radius_mean)
    for y in cdf.radius_mean:
            z_score=(y-mean_1)/std_1
            if np.abs(z_score)>threshold:
                outliers.append(y)
    return outliers

# %%
outlier_datapoints=detect_outlier(cdf)
print(outlier_datapoints)
# Out:
# [17.99, 20.57, 19.69, 20.29, 18.25, 19.17, 19.81, 9.504, 21.16, 18.61, 18.63, 19.27, 19.07, 18.65, 8.196, 18.22, 19.21, 8.618, 10.17, 8.597999999999999, 9.173, 9.465, 9.029, 18.94, 8.888, 18.05, 20.18, 25.22, 19.1, 18.46, 19.02, 20.26, 9.787, 6.981, 9.876, 10.49, 22.27, 9.777000000000001, 10.51, 8.726, 8.95, 17.95, 18.66, 24.25, 19.0, 19.79, 18.45, 9.738, 8.219, 9.731, 17.68, 19.19, 19.59, 23.27, 8.671, 9.904, 27.22, 21.09, 10.08, 18.31, 9.72, 18.08, 19.18, 23.29, 9.876, 20.58, 28.11, 10.2, 19.8, 19.53, 10.18, 10.44, 20.51, 9.567, 23.21, 20.48, 19.4, 10.48, 20.94, 19.73, 19.45, 19.55, 20.31, 20.73, 10.6, 21.75, 9.742, 17.93, 18.81, 19.16, 19.4, 10.51, 19.53, 20.09, 10.49, 9.0, 8.597000000000001, 18.22, 9.042, 10.25, 20.16, 20.34, 18.77, 10.05, 23.51, 9.606, 19.68, 10.26, 25.73, 8.878, 9.436, 20.44, 20.2, 21.71, 22.01, 21.37, 20.64, 10.57, 19.55, 10.26, 8.734, 21.61, 17.91, 17.99, 9.397, 9.405, 9.742, 10.03, 10.48, 20.18, 18.82, 10.57, 18.03, 17.75, 21.1, 19.59, 9.755, 27.42, 9.668, 9
# ...

# %%
c=0
min1=np.min(cdf['radius_mean'])
max1=np.max(cdf['radius_mean'])
print(min1,max1)
tempdf=cdf.loc[(cdf['radius_mean']<min1) & (cdf['radius_mean']>max1)]
# Out:
# 6.981 28.11
# 1
