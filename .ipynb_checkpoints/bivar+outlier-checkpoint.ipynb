# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("cancer.csv")
print(df)
df=df.drop(['id','Unnamed: 32'],axis=1)
df.head(10)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M       17.990         10.38          122.80     1001.0
# 1      842517         M       20.570         17.77          132.90     1326.0
# 2    84300903         M       19.690         21.25          130.00     1203.0
# 3    84348301         M       11.420         20.38           77.58      386.1
# 4    84358402         M       20.290         14.34          135.10     1297.0
# 5      843786         M       12.450         15.70           82.57      477.1
# 6      844359         M       18.250         19.98          119.60     1040.0
# 7    84458202         M       13.710         20.83           90.20      577.9
# 8      844981         M       13.000         21.82           87.50      519.8
# 9    84501001         M       12.460         24.04           83.97      475.9
# 10     845636         M       16.020         23.24          102.70      797.8
# ...

# %%
for i in df:
    df.describe()

# %%
df.ndim
# Out:
# 2

# %%
sns.barplot(x='diagnosis',y='radius_mean',data=df,palette='winter')

# %%
sns.barplot(x='diagnosis',y='radius_se',data=df,palette='winter')

# %%
sns.barplot(x='diagnosis',y='radius_worst',data=df,palette='winter')

# %%
sns.barplot(x='diagnosis',y='texture_mean',data=df,palette='winter')

# %%
sns.barplot(x='diagnosis',y='texture_se',data=df,palette='winter')

# %%
sns.barplot(x='diagnosis',y='texture_worst',data=df,palette='winter')

# %%
sns.barplot(x='diagnosis',y='perimeter_mean',data=df,palette='winter')

# %%
sns.barplot(x='diagnosis',y='perimeter_se',data=df,palette='winter')

# %%
sns.barplot(x='diagnosis',y='perimeter_worst',data=df,palette='winter')

# %%
sns.barplot(x='diagnosis',y='area_mean',data=df,palette='winter')

# %%
sns.barplot(x='diagnosis',y='area_se',data=df,palette='winter')

# %%
sns.barplot(x='diagnosis',y='area_worst',data=df,palette='winter')

# %%
sns.barplot(x='diagnosis',y='smoothness_mean',data=df,palette='winter')

# %%
sns.barplot(x='diagnosis',y='smoothness_se',data=df,palette='winter')

# %%
sns.barplot(x='diagnosis',y='smoothness_worst',data=df,palette='winter')

# %%
sns.barplot(x='diagnosis',y='compactness_mean',data=df,palette='winter')

# %%
sns.barplot(x='diagnosis',y='compactness_se',data=df,palette='winter')

# %%
sns.barplot(x='diagnosis',y='compactness_worst',data=df,palette='winter')

# %%
sns.barplot(x='diagnosis',y='concave points_mean',data=df,palette='winter')

# %%
sns.barplot(x='diagnosis',y='concave points_se',data=df,palette='winter')

# %%
sns.barplot(x='diagnosis',y='concave points_worst',data=df,palette='winter')

# %%
sns.barplot(x='diagnosis',y='symmetry_mean',data=df,palette='winter')

# %%
sns.barplot(x='diagnosis',y='symmetry_se',data=df,palette='winter')

# %%
sns.barplot(x='diagnosis',y='symmetry_worst',data=df,palette='winter')

# %%
sns.barplot(x='diagnosis',y='fractal_dimension_mean',data=df,palette='winter')

# %%
sns.barplot(x='diagnosis',y='fractal_dimension_se',data=df,palette='winter')

# %%
sns.barplot(x='diagnosis',y='fractal_dimension_worst',data=df,palette='winter')

# %%
sns.countplot(df['diagnosis'], label = "Count")

# %%
k=df['concavity_se'].mean(skipna=True)
print(k)
df['concavity_se']=df.concavity_se.mask(df.concavity_se==0,k)
print(df)
# Out:
# 0.03189371634446394
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M       17.990         10.38          122.80     1001.0
# 1           M       20.570         17.77          132.90     1326.0
# 2           M       19.690         21.25          130.00     1203.0
# 3           M       11.420         20.38           77.58      386.1
# 4           M       20.290         14.34          135.10     1297.0
# 5           M       12.450         15.70           82.57      477.1
# 6           M       18.250         19.98          119.60     1040.0
# 7           M       13.710         20.83           90.20      577.9
# 8           M       13.000         21.82           87.50      519.8
# 9           M       12.460         24.04           83.97      475.9
# 10          M       16.020         23.24          102.70      797.8
# 11          M       15.780         17.89          103.60      781.0
# ...

# %%
sns.distplot(df['concavity_se'])

# %%
df.skew()
# Out:
# radius_mean                0.942380
# texture_mean               0.650450
# perimeter_mean             0.990650
# area_mean                  1.645732
# smoothness_mean            0.456324
# compactness_mean           1.190123
# concavity_mean             1.401180
# concave points_mean        1.171180
# symmetry_mean              0.725609
# fractal_dimension_mean     1.304489
# radius_se                  3.088612
# texture_se                 1.646444
# perimeter_se               3.443615
# area_se                    5.447186
# smoothness_se              2.314450
# compactness_se             1.902221
# concavity_se               5.272078
# concave points_se          1.444678
# symmetry_se                2.195133
# fractal_dimension_se       3.923969
# radius_worst               1.103115
# texture_worst              0.498321
# perimeter_worst            1.128164
# area_worst                 1.859373
# smoothness_worst           0.415426
# compactness_worst          1.473555
# ...

# %%
df['concavity_se']=np.sqrt(np.sqrt(df['concavity_se']))
sns.distplot(df['concavity_se'])

# %%
df.skew()
# Out:
# radius_mean                0.942380
# texture_mean               0.650450
# perimeter_mean             0.990650
# area_mean                  1.645732
# smoothness_mean            0.456324
# compactness_mean           1.190123
# concavity_mean             1.401180
# concave points_mean        1.171180
# symmetry_mean              0.725609
# fractal_dimension_mean     1.304489
# radius_se                  3.088612
# texture_se                 1.646444
# perimeter_se               3.443615
# area_se                    5.447186
# smoothness_se              2.314450
# compactness_se             1.902221
# concavity_se               0.170158
# concave points_se          1.444678
# symmetry_se                2.195133
# fractal_dimension_se       3.923969
# radius_worst               1.103115
# texture_worst              0.498321
# perimeter_worst            1.128164
# area_worst                 1.859373
# smoothness_worst           0.415426
# compactness_worst          1.473555
# ...

# %%
sns.distplot(df['concavity_worst'])

# %%
df['concavity_worst']=np.sqrt(df['concavity_worst'])
sns.distplot(df['concavity_worst'])

# %%
df.skew()
# Out:
# radius_mean                0.942380
# texture_mean               0.650450
# perimeter_mean             0.990650
# area_mean                  1.645732
# smoothness_mean            0.456324
# compactness_mean           1.190123
# concavity_mean             1.401180
# concave points_mean        1.171180
# symmetry_mean              0.725609
# fractal_dimension_mean     1.304489
# radius_se                  3.088612
# texture_se                 1.646444
# perimeter_se               3.443615
# area_se                    5.447186
# smoothness_se              2.314450
# compactness_se             1.902221
# concavity_se               0.170158
# concave points_se          1.444678
# symmetry_se                2.195133
# fractal_dimension_se       3.923969
# radius_worst               1.103115
# texture_worst              0.498321
# perimeter_worst            1.128164
# area_worst                 1.859373
# smoothness_worst           0.415426
# compactness_worst          1.473555
# ...

# %%
df['radius_mean']=np.sqrt(np.sqrt(df['radius_mean']))
sns.distplot(df['radius_mean'])
df.skew()
# Out:
# radius_mean                0.464741
# texture_mean               0.650450
# perimeter_mean             0.990650
# area_mean                  1.645732
# smoothness_mean            0.456324
# compactness_mean           1.190123
# concavity_mean             1.401180
# concave points_mean        1.171180
# symmetry_mean              0.725609
# fractal_dimension_mean     1.304489
# radius_se                  3.088612
# texture_se                 1.646444
# perimeter_se               3.443615
# area_se                    5.447186
# smoothness_se              2.314450
# compactness_se             1.902221
# concavity_se               0.170158
# concave points_se          1.444678
# symmetry_se                2.195133
# fractal_dimension_se       3.923969
# radius_worst               1.103115
# texture_worst              0.498321
# perimeter_worst            1.128164
# area_worst                 1.859373
# smoothness_worst           0.415426
# compactness_worst          1.473555
# ...

# %%
df['texture_mean']=np.log(np.log(df['texture_mean']))
sns.distplot(df['texture_mean'])
df.skew()
# Out:
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-f62d9bf9693a> in <module>
#       1 df['texture_mean']=np.log(np.log(df['texture_mean']))
# ----> 2 sns.distplot(df['texture_mean'])
#       3 df.skew()
#
# F:\Anaconda\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     213     if hist:
#     214         if bins is None:
# --> 215             bins = min(_freedman_diaconis_bins(a), 50)
#     216         hist_kws.setdefault("alpha", 0.4)
#     217         if LooseVersion(mpl.__version__) < LooseVersion("2.2"):
#
# ...

# %%
#df['perimeter_mean']=np.log(df['perimeter_mean'])
sns.distplot(df['perimeter_mean'])
df.skew()
# Out:
# radius_mean                0.464741
# texture_mean              -0.234123
# perimeter_mean             0.990650
# area_mean                  1.645732
# smoothness_mean            0.456324
# compactness_mean           1.190123
# concavity_mean             1.401180
# concave points_mean        1.171180
# symmetry_mean              0.725609
# fractal_dimension_mean     1.304489
# radius_se                  3.088612
# texture_se                 1.646444
# perimeter_se               3.443615
# area_se                    5.447186
# smoothness_se              2.314450
# compactness_se             1.902221
# concavity_se               0.170158
# concave points_se          1.444678
# symmetry_se                2.195133
# fractal_dimension_se       3.923969
# radius_worst               1.103115
# texture_worst              0.498321
# perimeter_worst            1.128164
# area_worst                 1.859373
# smoothness_worst           0.415426
# compactness_worst          1.473555
# ...

# %%
df['perimeter_mean']=np.log(df['perimeter_mean'])
sns.distplot(df['perimeter_mean'])
df.skew()
# Out:
# radius_mean                0.464741
# texture_mean              -0.234123
# perimeter_mean             0.321425
# area_mean                  1.645732
# smoothness_mean            0.456324
# compactness_mean           1.190123
# concavity_mean             1.401180
# concave points_mean        1.171180
# symmetry_mean              0.725609
# fractal_dimension_mean     1.304489
# radius_se                  3.088612
# texture_se                 1.646444
# perimeter_se               3.443615
# area_se                    5.447186
# smoothness_se              2.314450
# compactness_se             1.902221
# concavity_se               0.170158
# concave points_se          1.444678
# symmetry_se                2.195133
# fractal_dimension_se       3.923969
# radius_worst               1.103115
# texture_worst              0.498321
# perimeter_worst            1.128164
# area_worst                 1.859373
# smoothness_worst           0.415426
# compactness_worst          1.473555
# ...

# %%
sns.distplot(df['area_mean'])
df.skew()
# Out:
# radius_mean                0.464741
# texture_mean              -0.234123
# perimeter_mean             0.321425
# area_mean                  1.645732
# smoothness_mean            0.456324
# compactness_mean           1.190123
# concavity_mean             1.401180
# concave points_mean        1.171180
# symmetry_mean              0.725609
# fractal_dimension_mean     1.304489
# radius_se                  3.088612
# texture_se                 1.646444
# perimeter_se               3.443615
# area_se                    5.447186
# smoothness_se              2.314450
# compactness_se             1.902221
# concavity_se               0.170158
# concave points_se          1.444678
# symmetry_se                2.195133
# fractal_dimension_se       3.923969
# radius_worst               1.103115
# texture_worst              0.498321
# perimeter_worst            1.128164
# area_worst                 1.859373
# smoothness_worst           0.415426
# compactness_worst          1.473555
# ...

# %%
df['area_mean']=np.sqrt(np.sqrt(np.sqrt(df['area_mean'])))
sns.distplot(df['area_mean'])
df.skew()
# Out:
# radius_mean                0.464741
# texture_mean              -0.234123
# perimeter_mean             0.321425
# area_mean                  0.608298
# smoothness_mean            0.456324
# compactness_mean           1.190123
# concavity_mean             1.401180
# concave points_mean        1.171180
# symmetry_mean              0.725609
# fractal_dimension_mean     1.304489
# radius_se                  3.088612
# texture_se                 1.646444
# perimeter_se               3.443615
# area_se                    5.447186
# smoothness_se              2.314450
# compactness_se             1.902221
# concavity_se               0.170158
# concave points_se          1.444678
# symmetry_se                2.195133
# fractal_dimension_se       3.923969
# radius_worst               1.103115
# texture_worst              0.498321
# perimeter_worst            1.128164
# area_worst                 1.859373
# smoothness_worst           0.415426
# compactness_worst          1.473555
# ...
